# %% [markdown]
# ## Generating a dataset
#
# Purpose: We want to assess the correlation of structure (e.g. lipophilicity) of some molecules with their inhibitory activity for Acetylcholinesterase (AChE). First of all:
#
# Import dependencies and load the two datasets for activities (ChEMBL) and molecular descriptors (PubChem).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load both datasets
act = pd.read_csv("ache_activities.csv")
desc = pd.read_csv("ache_pubchem_descriptors.csv")

# Keep only relevant columns from ChEMBL
act = act[["canonical_smiles", "pchembl_value", "standard_relation", "standard_type"]]

# Aggregate (some SMILES might appear multiple times → average or median)
act = act.groupby("canonical_smiles", as_index=False)["pchembl_value"].median()

# %% [markdown]
# Inspect the two datasets.

# %%
act.head()
# Out:
#                                     canonical_smiles  pchembl_value
# 0  Br.CC[N+](CC)(CCCCCn1c(=O)cc(C)n(CCCCCn2c(C)cc...           9.40
# 1  Br.CC[N+](CC)(CCCCCn1c(=O)cc(C)n(CCCCn2c(C)cc(...           9.22
# 2  Br.CC[N+](CC)(CCCCCn1c(=O)cc(C)n(CCCn2c(C)cc(=...           8.15
# 3  Br.COc1ccc2c3c1O[C@H]1C[C@@H](O)C=C[C@@]31CCN(...           5.50
# 4               Brc1ccc(-[n+]2ccc3ccccc3c2)cc1.[Br-]           5.62

# %%
desc.head()
# Out:
#                                 canonical_smiles       CID  MolecularWeight  \
# 0                 c1ccc(-c2nnc(NCN3CCCCC3)s2)cc1  46889617           274.39
# 1                c1ccc(-c2cnc(NCN3CCCCC3)nn2)cc1  46889618           269.34
# 2      O=C(CCC1CCN(Cc2ccccc2)CC1)c1ccc2c(c1)OCO2  46889660           351.40
# 3  Cc1nc2cc(C(=O)CCC3CCN(Cc4ccccc4)CC3)ccc2[nH]1  10292083           361.50
# 4      Cc1ccc(C(=O)NC(=S)NCCOCCN(C)Cc2ccccc2)cc1  10091498           385.50
#
#    XLogP  TPSA  HBondDonorCount  HBondAcceptorCount  RotatableBondCount
# 0    3.3  69.3                1                 5.0                   4
# 1    2.2  53.9                1                 5.0                   4
# 2    4.0  38.8                0                 4.0                   6
# 3    4.1  49.0                1                 3.0                   6
# 4    3.7  85.7                2                 4.0                   9

# %%
desc.shape
# Out:
# (200, 8)

# %% [markdown]
# Combine the two datasets.

# %%
# Merge on canonical_smiles, how="inner" drops all rows which are only contained in one df
merged = pd.merge(act, desc, on="canonical_smiles", how="inner") 

print(f"Merged dataset: {len(merged)} entries")
merged.head()
# Out:
# Merged dataset: 200 entries
#                                     canonical_smiles  pchembl_value  \
# 0                   C#CCCOC[n+]1ccc(/C=N/O)cc1.[Cl-]           4.01
# 1            C(=C/C1CCN(Cc2ccccc2)CC1)\c1noc2ccccc12           6.68
# 2  C/C=C1\[C@H]2C=C(C)C[C@]1(NC1OCC3=C4CC(C)(C)C[...           6.96
# 3  C/C=C1\[C@H]2C=C(C)C[C@]1(N[C@H]1OC(=O)C3=C4CC...           5.66
# 4  C=CC(=O)N1C/C(=C\c2ccc(C)cc2)C(=O)/C(=C/c2ccc(...           4.74
#
#          CID  MolecularWeight  XLogP   TPSA  HBondDonorCount  \
# 0  135909812           240.68    NaN   45.7                1
# 1    9901561           318.40    4.5   29.3                0
# 2  118715261           492.60    1.2   90.8                4
# 3  118715260           506.60    1.5  108.0                4
# 4   24796898           357.40    4.4   37.4                0
#
#    HBondAcceptorCount  RotatableBondCount
# 0                 4.0                   5
# 1                 3.0                   4
# 2                 5.0                   2
# 3                 6.0                   2
# 4                 2.0                   3

# %% [markdown]
# Now, inspect the combined dataframe. Look for abnomalies, i.e. duplicates and missing data.

# %%
merged.duplicated().sum()
# Out:
# np.int64(14)

# %%
merged.describe()
# Out:
#        pchembl_value           CID  MolecularWeight       XLogP        TPSA  \
# count     200.000000  2.000000e+02       198.000000  178.000000  198.000000
# mean        6.197600  4.981526e+07       402.229242    4.301685   64.247980
# std         1.334509  4.792839e+07       115.194690    1.831441   32.207804
# min         4.010000  1.338000e+03       110.130000    0.100000    0.000000
# 25%         5.012500  1.057273e+07       337.175000    2.800000   40.600000
# 50%         6.100000  4.433380e+07       392.950000    4.300000   59.350000
# 75%         7.132500  7.630888e+07       457.900000    5.300000   85.450000
# max         9.570000  1.646256e+08       801.000000   10.200000  183.000000
#
#        HBondDonorCount  HBondAcceptorCount  RotatableBondCount
# count       200.000000          199.000000          200.000000
# mean          1.180000            4.567839            6.275000
# std           1.059819            1.867903            5.340598
# min           0.000000            1.000000            0.000000
# 25%           0.000000            3.000000            3.000000
# 50%           1.000000            4.000000            5.000000
# 75%           2.000000            6.000000            9.000000
# max           5.000000           11.000000           31.000000

# %%
merged[merged.duplicated(keep=False)]
# Out:
#                                       canonical_smiles  pchembl_value  \
# 63     CCOC(=O)c1c(C)nc2nc3c(c(N)c2c1-c1ccccc1)CCCCCC3          4.770
# 64     CCOC(=O)c1c(C)nc2nc3c(c(N)c2c1-c1ccccc1)CCCCCC3          4.770
# 71   CC[N+](CC)(CC)CCOc1ccc(C(=O)NCCCCCC(=O)NNc2c3c...          8.120
# 72   CC[N+](CC)(CC)CCOc1ccc(C(=O)NCCCCCC(=O)NNc2c3c...          8.120
# 93   CNC(=O)Oc1cccc(CN(C)CCCOc2ccc3c(=O)c4ccccc4oc3...          9.520
# 94   CNC(=O)Oc1cccc(CN(C)CCCOc2ccc3c(=O)c4ccccc4oc3...          9.520
# 108      COc1cc2c(cc1OC)C(=O)C(CC1CCN(Cc3ccccc3)CC1)C2          7.750
# 109      COc1cc2c(cc1OC)C(=O)C(CC1CCN(Cc3ccccc3)CC1)C2          7.750
# 110      COc1cc2c(cc1OC)C(=O)C(CC1CCN(Cc3ccccc3)CC1)C2          7.750
# 111      COc1cc2c(cc1OC)C(=O)C(CC1CCN(Cc3ccccc3)CC1)C2          7.750
# 112      COc1cc2c(cc1OC)C(=O)C(CC1CCN(Cc3ccccc3)CC1)C2          7.750
# 135                                       Cc1ccc(F)cc1          6.665
# 136                                       Cc1ccc(F)cc1          6.665
# 159                         Nc1c2c(nc3cc(F)ccc13)CCCC2          7.060
# 160                         Nc1c2c(nc3cc(F)ccc13)CCCC2          7.060
# 164                            Nc1c2c(nc3ccccc13)CCCC2          6.640
# 165                            Nc1c2c(nc3ccccc13)CCCC2          6.640
# 166                            Nc1c2c(nc3ccccc13)CCCC2          6.640
# 167                            Nc1c2c(nc3ccccc13)CCCC2          6.640
# 168                            Nc1c2c(nc3ccccc13)CCCC2          6.640
# 197  c1cnc2nc3c(c(NCCCCCCCNc4c5c(nc6ncccc46)CCCC5)c...          8.890
# 198  c1cnc2nc3c(c(NCCCCCCCNc4c5c(nc6ncccc46)CCCC5)c...          8.890
#
#           CID  MolecularWeight  XLogP  TPSA  HBondDonorCount  \
# 63   76318775           389.50    5.3  78.1                1
# 64   76318775           389.50    5.3  78.1                1
# 71   23657682           691.10    NaN  92.4                4
# 72   23657682           691.10    NaN  92.4                4
# 93   10765787           446.50    4.4  77.1                1
# 94   10765787           446.50    4.4  77.1                1
# 108      3152           379.50    4.3  38.8                0
# 109      3152           379.50    4.3  38.8                0
# 110      3152           379.50    4.3  38.8                0
# 111      3152           379.50    4.3  38.8                0
# 112      3152           379.50    4.3  38.8                0
# 135      9603           110.13    2.8   0.0                0
# 136      9603           110.13    2.8   0.0                0
# 159  10013554           216.25    2.8  38.9                1
# 160  10013554           216.25    2.8  38.9                1
# 164      1935           198.26    2.7  38.9                1
# 165      1935           198.26    2.7  38.9                1
# 166      1935           198.26    2.7  38.9                1
# 167      1935           198.26    2.7  38.9                1
# 168      1935           198.26    2.7  38.9                1
# 197  23644779           494.70    7.1  75.6                2
# 198  23644779           494.70    7.1  75.6                2
#
#      HBondAcceptorCount  RotatableBondCount
# 63                  5.0                   4
# 64                  5.0                   4
# 71                  6.0                  16
# 72                  6.0                  16
# 93                  6.0                   9
# 94                  6.0                   9
# 108                 4.0                   6
# 109                 4.0                   6
# 110                 4.0                   6
# 111                 4.0                   6
# 112                 4.0                   6
# 135                 1.0                   0
# 136                 1.0                   0
# 159                 3.0                   0
# 160                 3.0                   0
# 164                 2.0                   0
# 165                 2.0                   0
# 166                 2.0                   0
# 167                 2.0                   0
# 168                 2.0                   0
# 197                 6.0                  10
# 198                 6.0                  10

# %%
# dropped incidentally created duplicates
df_clean = merged.drop_duplicates()
df_clean.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Decide what to do with the bad data points and proceed. Make sure to document properly and preserve the original dataframe.

# %%
df_clean.isna().sum()
# Out:
# canonical_smiles      0
# pchembl_value         0
# CID                   0
# MolecularWeight       2
# XLogP                 0
# TPSA                  2
# HBondDonorCount       0
# HBondAcceptorCount    1
# RotatableBondCount    0
# dtype: int64

# %%
# drop rows with na in column xlogp
df_clean = df_clean.dropna(subset=["XLogP"])

# %% [markdown]
# Run a quick EDA on the cleaned dataset including some plots. What can you conclude?

# %%
df_clean.hist(figsize=(10, 8), bins=15)
plt.show()

# %%
# make a scatter plot of XLogP

# %% [markdown]
# Export the cleaned dataset as "ache_qsar_data.csv".

# %%
df_clean.to_csv("ache_qsar_data.csv")
